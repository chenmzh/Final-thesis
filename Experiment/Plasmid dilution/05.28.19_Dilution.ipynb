# %%
ExperimentIndex = 'Run1_Numxx_'
BlueChannel = 'Pacific Blue-A'#'BV 421-A'
GreenChannel = 'FITC-A'
#RedChannel = 'PE-Texas Red-A'
#iRedChannel = 'APC-Cy7-A'

FolderWithFlowFiles = 'C:/Git-project/Project-Strutualize-demo/Projects/Asymmetric cell division/Experiment/data/Ming/'
#FolderWithFlowFiles = 'Z:/home/chenmzh/incoming/030919_MingPhloretin/FACS/'

BeadName            = FolderWithFlowFiles+"Specimen_001_AK04Beads_063.fcs"
BlankControlName    = FolderWithFlowFiles+"Specimen_013_C1_C01_001.fcs"
MultiControl        = FolderWithFlowFiles+"Specimen_022_C10_C10_010.fcs"
BlueControlName     = FolderWithFlowFiles+"Specimen_016_C4_C04_004.fcs"
YellowControlName   = FolderWithFlowFiles+"Specimen_019_C7_C07_007.fcs"
#RedControlName      = FolderWithFlowFiles+"Specimen_070_A10_A10_021.fcs"

inputs = {
     ('1'    ,'1' ,'12h-multi')                    :FolderWithFlowFiles+'Specimen_074_H12_H12_062.fcs',
     ('1'    ,'2' ,'12h-multi')                    :FolderWithFlowFiles+'Specimen_073_H11_H11_061.fcs',
     ('1'    ,'3' ,'12h-multi')                    :FolderWithFlowFiles+'Specimen_072_H10_H10_060.fcs',
    
     ('2'    ,'1' ,'12h-T')                        :FolderWithFlowFiles+'Specimen_062_G12_G12_050.fcs',
     ('2'    ,'2' ,'12h-T')                        :FolderWithFlowFiles+'Specimen_061_G11_G11_049.fcs',
     ('2'    ,'3' ,'12h-T')                        :FolderWithFlowFiles+'Specimen_060_G10_G10_048.fcs',
    
     ('3'    ,'1' ,'48h-multi')                    :FolderWithFlowFiles+'Specimen_059_F12_F12_047.fcs',
     ('3'    ,'2' ,'48h-multi')                    :FolderWithFlowFiles+'Specimen_058_F11_F11_046.fcs',
     ('3'    ,'3' ,'48h-multi')                    :FolderWithFlowFiles+'Specimen_057_F10_F10_045.fcs',

     ('4'    ,'1' ,'96h-multi-96well')             :FolderWithFlowFiles+'Specimen_047_E12_E12_035.fcs',
     ('4'    ,'2' ,'96h-multi-96well')             :FolderWithFlowFiles+'Specimen_046_E11_E11_034.fcs',
     ('4'    ,'3' ,'96h-multi-96well')             :FolderWithFlowFiles+'Specimen_045_E10_E10_033.fcs',
    
     ('5'    ,'1' ,'96h-multi-24well')             :FolderWithFlowFiles+'Specimen_036_D12_D12_024.fcs',
     ('5'    ,'2' ,'96h-multi-24well')             :FolderWithFlowFiles+'Specimen_035_D11_D11_023.fcs',
     ('5'    ,'3' ,'96h-multi-24well')             :FolderWithFlowFiles+'Specimen_034_D10_D10_022.fcs',
    
     ('6'    ,'1' ,'144h-multi-24well')            :FolderWithFlowFiles+'Specimen_024_C12_C12_012.fcs',
     ('6'    ,'2' ,'144h-multi-24well')            :FolderWithFlowFiles+'Specimen_023_C11_C11_011.fcs',
     ('6'    ,'3' ,'144h-multi-24well')            :FolderWithFlowFiles+'Specimen_022_C10_C10_010.fcs',

    
    
    ('7'    ,'1' ,'12h-Green')                     :FolderWithFlowFiles+'Specimen_071_H9_H09_059.fcs',
    ('7'    ,'2' ,'12h-Green')                     :FolderWithFlowFiles+'Specimen_070_H8_H08_058.fcs',
    ('7'    ,'3' ,'12h-Green')                     :FolderWithFlowFiles+'Specimen_069_H7_H07_057.fcs', 
    
    ('8'    ,'1' ,'48h-Green')                     :FolderWithFlowFiles+'Specimen_056_F9_F09_044.fcs',
    ('8'    ,'2' ,'48h-Green')                     :FolderWithFlowFiles+'Specimen_055_F8_F08_043.fcs',
    ('8'    ,'3' ,'48h-Green')                     :FolderWithFlowFiles+'Specimen_054_F7_F07_042.fcs',

    ('9'    ,'1' ,'96h-Green-96well')              :FolderWithFlowFiles+'Specimen_044_E9_E09_032.fcs',
    ('9'    ,'2' ,'96h-Green-96well')              :FolderWithFlowFiles+'Specimen_043_E8_E08_031.fcs',
    ('9'    ,'3' ,'96h-Green-96well')              :FolderWithFlowFiles+'Specimen_042_E7_E07_030.fcs',
    
    ('10'    ,'1' ,'96h-Green-24well')             :FolderWithFlowFiles+'Specimen_033_D9_D09_021.fcs',
    ('10'    ,'2' ,'96h-Green-24well')             :FolderWithFlowFiles+'Specimen_032_D8_D08_020.fcs',
    ('10'    ,'3' ,'96h-Green-24well')             :FolderWithFlowFiles+'Specimen_031_D7_D07_019.fcs',   

    ('11'    ,'1' ,'144h-Green-24well')            :FolderWithFlowFiles+'Specimen_021_C9_C09_009.fcs',
    ('11'    ,'2' ,'144h-Green-24well')            :FolderWithFlowFiles+'Specimen_020_C8_C08_008.fcs',
    ('11'    ,'3' ,'144h-Green-24well')            :FolderWithFlowFiles+'Specimen_019_C7_C07_007.fcs', 
    
    
    
    
    ('12'    ,'1' ,'12h-Blue')                     :FolderWithFlowFiles+'Specimen_068_H6_H06_056.fcs',
    ('12'    ,'2' ,'12h-Blue')                     :FolderWithFlowFiles+'Specimen_067_H5_H05_055.fcs',
    ('12'    ,'3' ,'12h-Blue')                     :FolderWithFlowFiles+'Specimen_066_H4_H04_054.fcs',
     
    
    ('13'    ,'1' ,'48h-Blue')                     :FolderWithFlowFiles+'Specimen_053_F6_F06_041.fcs',
    ('13'    ,'2' ,'48h-Blue')                     :FolderWithFlowFiles+'Specimen_052_F5_F05_040.fcs',
    ('13'    ,'3' ,'48h-Blue')                     :FolderWithFlowFiles+'Specimen_051_F4_F04_039.fcs',

    ('14'    ,'1' ,'96h-Blue-96well')              :FolderWithFlowFiles+'Specimen_041_E5_E05_029.fcs',
    ('14'    ,'2' ,'96h-Blue-96well')              :FolderWithFlowFiles+'Specimen_040_E4_E04_028.fcs',

    ('15'    ,'1' ,'96h-Blue-24well')              :FolderWithFlowFiles+'Specimen_030_D6_D06_018.fcs',
    ('15'    ,'2' ,'96h-Blue-24well')              :FolderWithFlowFiles+'Specimen_029_D5_D05_017.fcs',
    ('15'    ,'3' ,'96h-Blue-24well')              :FolderWithFlowFiles+'Specimen_028_D4_D04_016.fcs',   

    ('16'    ,'1' ,'144h-Blue-24well')             :FolderWithFlowFiles+'Specimen_018_C6_C06_006.fcs',
    ('16'    ,'2' ,'144h-Blue-24well')             :FolderWithFlowFiles+'Specimen_017_C5_C05_005.fcs',
    ('16'    ,'3' ,'144h-Blue-24well')             :FolderWithFlowFiles+'Specimen_016_C4_C04_004.fcs',   
    
    
    
 
    
    ('17'    ,'1' ,'12h-Blank')                     :FolderWithFlowFiles+'Specimen_065_H3_H03_053.fcs',
    ('17'    ,'2' ,'12h-Blank')                     :FolderWithFlowFiles+'Specimen_064_H2_H02_052.fcs',
    ('17'    ,'3' ,'12h-Blank')                     :FolderWithFlowFiles+'Specimen_063_H1_H01_051.fcs',
     
    
    ('18'    ,'1' ,'48h-Blank')                     :FolderWithFlowFiles+'Specimen_050_F3_F03_038.fcs',
    ('18'    ,'2' ,'48h-Blank')                     :FolderWithFlowFiles+'Specimen_049_F2_F02_037.fcs',
    ('18'    ,'3' ,'48h-Blank')                     :FolderWithFlowFiles+'Specimen_048_F1_F01_036.fcs',


    ('19'    ,'1' ,'96h-Blank-96well')              :FolderWithFlowFiles+'Specimen_039_E3_E03_027.fcs',
    ('19'    ,'2' ,'96h-Blank-96well')              :FolderWithFlowFiles+'Specimen_038_E2_E02_026.fcs',
    ('19'    ,'3' ,'96h-Blank-96well')              :FolderWithFlowFiles+'Specimen_037_E1_E01_025.fcs',

    ('20'    ,'1' ,'96h-Blank-24well')              :FolderWithFlowFiles+'Specimen_027_D3_D03_015.fcs',
    ('20'    ,'2' ,'96h-Blank-24well')              :FolderWithFlowFiles+'Specimen_026_D2_D02_014.fcs',
    ('20'    ,'3' ,'96h-Blank-24well')              :FolderWithFlowFiles+'Specimen_025_D1_D01_013.fcs',   

    ('21'    ,'1' ,'144h-Blank-24well')             :FolderWithFlowFiles+'Specimen_015_C3_C03_003.fcs',
    ('21'    ,'2' ,'144h-Blank-24well')             :FolderWithFlowFiles+'Specimen_014_C2_C02_002.fcs',
    ('21'    ,'3' ,'144h-Blank-24well')             :FolderWithFlowFiles+'Specimen_013_C1_C01_001.fcs',      

      
}

# %%
import matplotlib.pyplot as plt
import numpy as np
import cytoflow as flow
from scipy import stats
#%matplotlib inline

# %%
ExperimentIndex = 'Run1_Numxx_'
BlueChannel = 'Pacific Blue-A'#'BV 421-A'
GreenChannel = 'FITC-A'
#RedChannel = 'PE-Texas Red-A'
#iRedChannel = 'APC-Cy7-A'

FolderWithFlowFiles = 'C:/Git-project/Project-Strutualize-demo/Projects/Asymmetric cell division/Experiment/data/Ming/'
#FolderWithFlowFiles = 'Z:/home/chenmzh/incoming/030919_MingPhloretin/FACS/'

BeadName            = FolderWithFlowFiles+"Specimen_001_AK04Beads_063.fcs"
BlankControlName    = FolderWithFlowFiles+"Specimen_050_F3_F03_038.fcs"
MultiControl        = FolderWithFlowFiles+"Specimen_059_F12_F12_047.fcs"
BlueControlName     = FolderWithFlowFiles+"Specimen_053_F6_F06_041.fcs"
YellowControlName   = FolderWithFlowFiles+"Specimen_019_C7_C07_007.fcs"
#RedControlName      = FolderWithFlowFiles+"Specimen_070_A10_A10_021.fcs"

inputs = {
    
    ('9'    ,'1' ,'96h-Green-96well')              :FolderWithFlowFiles+'Specimen_044_E9_E09_032.fcs',
    ('9'    ,'2' ,'96h-Green-96well')              :FolderWithFlowFiles+'Specimen_043_E8_E08_031.fcs',
    ('9'    ,'3' ,'96h-Green-96well')              :FolderWithFlowFiles+'Specimen_042_E7_E07_030.fcs',
    
\
}

# %%
tubes = []

for (abrevKey, repKey, sampleKey), filename in inputs.items(): #Python 3.0
    tube = flow.Tube(file = filename,
                     conditions = {'Abreviation' : abrevKey,
                                   'Rep' : repKey,
                                   'Sample' : sampleKey})
    tubes.append(tube)

import_op = flow.ImportOp(conditions = {'Abreviation' : "category",
                                        'Rep' : "category",
                                        'Sample' : "category"},
                          tubes = tubes)
ex = import_op.apply()

# %%
ex.data.columns.values
# Out:
# array(['APC-A', 'APC-Cy7-A', 'Abreviation', 'Alexa Fluor 700-A',
#        'AmCyan-A', 'BUV 396-A', 'BUV 737-A', 'FITC-A', 'FSC-A', 'FSC-H',
#        'FSC-W', 'PE-A', 'PE-Cy5-A', 'PE-Cy7-A', 'PE-Texas Red-A',
#        'Pacific Blue-A', 'PerCP-Cy5-5-A', 'Qdot 605-A', 'Qdot 705-A',
#        'Qdot 800-A', 'Rep', 'SSC-A', 'SSC-H', 'SSC-W', 'Sample', 'Time'],
#       dtype=object)

# %%
flow.ScatterplotView(xchannel = "FSC-A",
                     ychannel = "SSC-A",
                     yscale = "log").plot(ex, alpha = 0.005)
plt.xlim((0,300000));

# %%
# %matplotlib inline
gm_1 = flow.GaussianMixture2DOp(name = "Morpho1",
                                xchannel = "FSC-A",
                                ychannel = "SSC-A",
                                yscale = "log",
                                num_components = 2,
                                sigma = 4)
gm_1.estimate(ex)
gm_1.default_view().plot(ex, alpha = 0.005)
plt.ylim((0.1,100000));
ex_morpho1 = gm_1.apply(ex)
#h = plt.gcf()
#h.savefig(ExperimentIndex+'Morpho1.png')
# Out:
# C:\Users\User\Anaconda3\envs\cf\lib\site-packages\cytoflow\operations\gaussian_2d.py:209: CytoflowOpWarning: GaussianMixture2DOp is DEPRECATED.  Please use GaussianMixtureOp.
# C:\Users\User\Anaconda3\envs\cf\lib\site-packages\cytoflow\operations\gaussian_2d.py:581: CytoflowOpWarning: GaussianMixture1DOp is DEPRECATED.  Please use GaussianMixtureOp.
# C:\Users\User\Anaconda3\envs\cf\lib\site-packages\cytoflow\operations\gaussian_2d.py:335: CytoflowOpWarning: GaussianMixture2DOp is DEPRECATED.  Please use GaussianMixtureOp.
# C:\Users\User\Anaconda3\envs\cf\lib\site-packages\cytoflow\utility\log_scale.py:131: RuntimeWarning: overflow encountered in power

# %%
flow.ScatterplotView(xchannel = "FSC-A",
                     ychannel = "SSC-A",
                     yscale = "log",
                     subset = "'Morpho1_2' in Morpho1").plot(ex_morpho1, alpha = 0.005)
#h = plt.gcf()
#h.savefig(ExperimentIndex+'Morpho1Check.png')

# %%
MorphoString = "'Morpho1_2' in Morpho1"
flow.ScatterplotView(xchannel = "FSC-W",
                     ychannel = "FSC-H",
                     subset = MorphoString).plot(ex_morpho1, alpha = 0.1)
plt.ylim((0.1,200000));
plt.xlim((0.1,200000));

# %%
MorphoString = "'Morpho1_2' in Morpho1"
gm_1 = flow.GaussianMixture2DOp(name = "Morpho2",
                                xchannel = "FSC-W",
                                ychannel = "FSC-H",
                                num_components = 1,
                                sigma = 4)
gm_1.estimate(ex_morpho1,subset = MorphoString)
gm_1.default_view(subset = MorphoString).plot(ex_morpho1, alpha = 0.005)
plt.ylim((0.1,200000));
plt.xlim((0.1,200000));
ex_morpho2 = gm_1.apply(ex_morpho1)
#h = plt.gcf()
#h.savefig(ExperimentIndex+'Morpho2.png')
# Out:
# C:\Users\User\Anaconda3\envs\cf\lib\site-packages\cytoflow\operations\gaussian_2d.py:209: CytoflowOpWarning: GaussianMixture2DOp is DEPRECATED.  Please use GaussianMixtureOp.
# C:\Users\User\Anaconda3\envs\cf\lib\site-packages\cytoflow\operations\gaussian_2d.py:581: CytoflowOpWarning: GaussianMixture1DOp is DEPRECATED.  Please use GaussianMixtureOp.
# C:\Users\User\Anaconda3\envs\cf\lib\site-packages\cytoflow\operations\gaussian_2d.py:335: CytoflowOpWarning: GaussianMixture2DOp is DEPRECATED.  Please use GaussianMixtureOp.

# %%
MorphoString = "'Morpho1_2' in Morpho1 and Morpho2 == True"
flow.ScatterplotView(xchannel = "FSC-W",
                     ychannel = "FSC-H",
                     subset = MorphoString).plot(ex_morpho2, alpha = 0.005)
plt.ylim((0.1,200000));
#h = plt.gcf()
#h.savefig(ExperimentIndex+'Morpho2Check.png')

# %%
flow.ScatterplotView(xchannel = "SSC-W",
                     ychannel = "SSC-H",
                     xscale = "log",
                     yscale = "log",
                     subset = MorphoString).plot(ex_morpho2, alpha = 0.005)
#h = plt.gcf()
#h.savefig(ExperimentIndex+'EndMorphoCheck.png')

# %%
ex_morpho2.data.columns.values
# Out:
# array(['APC-A', 'APC-Cy7-A', 'Abreviation', 'Alexa Fluor 700-A',
#        'AmCyan-A', 'BUV 396-A', 'BUV 737-A', 'FITC-A', 'FSC-A', 'FSC-H',
#        'FSC-W', 'PE-A', 'PE-Cy5-A', 'PE-Cy7-A', 'PE-Texas Red-A',
#        'Pacific Blue-A', 'PerCP-Cy5-5-A', 'Qdot 605-A', 'Qdot 705-A',
#        'Qdot 800-A', 'Rep', 'SSC-A', 'SSC-H', 'SSC-W', 'Sample', 'Time',
#        'Morpho1', 'Morpho2'], dtype=object)

# %%
#ex_morpho2.data

# %%
af_op = flow.AutofluorescenceOp()
af_op.blank_file = BlankControlName
af_op.channels = [GreenChannel,BlueChannel]
af_op.estimate(ex_morpho2, subset = MorphoString)
af_op.default_view().plot(ex_morpho2)
plt.rcParams["figure.figsize"] = [10,10]
ex_af = af_op.apply(ex_morpho2)

#h = plt.gcf()
#h.savefig(ExperimentIndex+'AF.png', transparent=True, bbox_inches='tight')
#ex_af = ex_morpho2
# Out:
# C:\Users\User\Anaconda3\envs\cf\lib\site-packages\cytoflow\operations\gaussian_2d.py:335: CytoflowOpWarning: GaussianMixture2DOp is DEPRECATED.  Please use GaussianMixtureOp.
# C:\Users\User\Anaconda3\envs\cf\lib\site-packages\cytoflow\utility\log_scale.py:131: RuntimeWarning: overflow encountered in power
# C:\Users\User\Anaconda3\envs\cf\lib\site-packages\cytoflow\operations\gaussian_2d.py:335: CytoflowOpWarning: GaussianMixture2DOp is DEPRECATED.  Please use GaussianMixtureOp.

# %%
bl_op = flow.BleedthroughLinearOp()
bl_op.controls = {GreenChannel   : YellowControlName,
                  BlueChannel    : BlueControlName}
bl_op.estimate(ex_af, subset = MorphoString)
bl_op.default_view().plot(ex_af)

# %time ex_bl = bl_op.apply(ex_af)

#h = plt.gcf()
#h.savefig(ExperimentIndex+'Bleed.png')
#ex_bl = ex_af
# Out:
# C:\Users\User\Anaconda3\envs\cf\lib\site-packages\cytoflow\operations\gaussian_2d.py:335: CytoflowOpWarning: GaussianMixture2DOp is DEPRECATED.  Please use GaussianMixtureOp.
# C:\Users\User\Anaconda3\envs\cf\lib\site-packages\cytoflow\utility\log_scale.py:131: RuntimeWarning: overflow encountered in power
# C:\Users\User\Anaconda3\envs\cf\lib\site-packages\cytoflow\operations\gaussian_2d.py:335: CytoflowOpWarning: GaussianMixture2DOp is DEPRECATED.  Please use GaussianMixtureOp.
# C:\Users\User\Anaconda3\envs\cf\lib\site-packages\cytoflow\operations\gaussian_2d.py:335: CytoflowOpWarning: GaussianMixture2DOp is DEPRECATED.  Please use GaussianMixtureOp.
# C:\Users\User\Anaconda3\envs\cf\lib\site-packages\cytoflow\utility\log_scale.py:131: RuntimeWarning: overflow encountered in power
# C:\Users\User\Anaconda3\envs\cf\lib\site-packages\cytoflow\operations\gaussian_2d.py:335: CytoflowOpWarning: GaussianMixture2DOp is DEPRECATED.  Please use GaussianMixtureOp.
# Wall time: 26 s

# %%
#bead_op = flow.BeadCalibrationOp()
#bead_op.beads = flow.BeadCalibrationOp.BEADS["Spherotech RCP-30-5A Lot AK02, AK03, AK04"] #we used AK04 need to update
#bead_op.units = {BlueChannel : "MEFL",
#                 GreenChannel : "MEFL"}

#bead_op.bead_brightness_threshold = 80
#bead_op.beads_file = BeadName
#bead_op.estimate(ex_bl)

#bead_op.default_view().plot(ex_bl)

#ex_beads = bead_op.apply(ex_bl)
ex_beads = ex_bl

#h = plt.gcf()
#h.set_size_inches(8,40)
#h.savefig(ExperimentIndex+'Beads.png')

# %%
## NOTE sample so sparce had to remove Morpho Gate...
#ct_op = flow.ColorTranslationOp()
#ct_op.translation = {BlueChannel : GreenChannel}
#ct_op.controls = {(BlueChannel, GreenChannel) : MultiControl}
#ct_op.mixture_model = True

#ct_op.estimate(ex_beads,subset = MorphoString)
#ct_op.default_view().plot(ex_beads)
#ex_calib = ct_op.apply(ex_beads)
ex_calib = ex_beads

#h = plt.gcf()
#h.savefig(ExperimentIndex+'Color.png', transparent=True, bbox_inches='tight')

# %% [markdown]
# # Write to CSV

# %%
for abrev in np.unique(ex_calib.data['Abreviation']):
    FileName = abrev+'.csv'
    Data2LookAt = MorphoString+" and ('"+abrev+"' in Abreviation)"
    DataForCSV = ex_calib.data.query(Data2LookAt)
    DataForCSV.to_csv(FileName)

# %%
ex2 = ex_calib.query("'15' in Abreviation or '16' in Abreviation")
thresh_op = flow.ThresholdOp(name = 'Threshold',
                             channel = BlueChannel,
                             threshold = 100)
tv = thresh_op.default_view(huefacet = "Sample",scale = 'log')
tv.plot(ex2)
ex3 = thresh_op.apply(ex2)
test = ex3.data.groupby(['Threshold','Abreviation']).size()
h = plt.gcf()
h.savefig('Cell counting for single blue')

# %%
test
# Out:
# Threshold  Abreviation
# False      5              569600
#            4              300579
# True       5               69584
#            4               64173
# dtype: int64

# %%
ex2 = ex_calib.query("'9' in Abreviation and '2' in Rep")
thresh_op = flow.ThresholdOp(name = 'Threshold',
                             channel = GreenChannel,
                             threshold = 100000)
tv = thresh_op.default_view(huefacet = "Sample",scale = 'log')
tv.plot(ex2)
ex3 = thresh_op.apply(ex2)
test = ex3.data.groupby(['Threshold','Abreviation']).size()
h = plt.gcf()
#h.savefig('Cell counting')

# %%
ex2 = ex_calib.query("'9' in Abreviation and '3' in Rep")
thresh_op = flow.ThresholdOp(name = 'Threshold',
                             channel = GreenChannel,
                             threshold = 100000)
tv = thresh_op.default_view(huefacet = "Sample",scale = 'log')
tv.plot(ex2)
ex3 = thresh_op.apply(ex2)
test = ex3.data.groupby(['Threshold','Abreviation']).size()
h = plt.gcf()
#h.savefig('Cell counting')

# %%
test
# Out:
# Threshold  Abreviation
# False      11             397655
# True       11               4621
# dtype: int64

# %%
test = flow.Stats1DView(statistic = ("Output", "geom_mean"),
                 variable = "Transfection_Bin",
                 huefacet = "Sample",
                 xscale = "log",
                 #yscale = "log",
                 error_statistic = ("Output","Replicate SEM")).plot(ex_stats)
plt.xlim((1,100000));
plt.ylim((1,200000));
plt.yscale('log')
#h = plt.figure(figsize=(100,100))
h = plt.gcf()
h.savefig('output vs geom_mean')
# Out:
# C:\Users\User\Anaconda3\envs\cf\lib\site-packages\cytoflow\utility\custom_traits.py:251: CytoflowWarning: Trait xscale is deprecated; please use variable_scale
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-df5f25b64816> in <module>
#       4                  xscale = "log",
#       5                  #yscale = "log",
# ----> 6                  error_statistic = ("Output","Replicate SEM")).plot(ex_stats)
#       7 plt.xlim((1,100000));
#       8 plt.ylim((1,200000));
#
# NameError: name 'ex_stats' is not defined

# %%
#DatatoLookAt= "Transfected == True and Transfection_Bin_Count > 500"
DatatoLookAt = MorphoString+" and ('3' in Abreviation)"
ex_stats = flow.ChannelStatisticOp(name = "Output",
                                   channel = GreenChannel,
                                   by = ["Sample","Transfection_Bin"],
                                   function = flow.geom_mean,
                                   subset = DatatoLookAt).apply(ex_bin)

ex_stats = flow.ChannelStatisticOp(name = "Output",
                                  channel = GreenChannel,
                                  by = ["Sample","Transfection_Bin"],
                                  function = lambda x: np.std(x) / np.sqrt(len(x)),
                                  statistic_name = "Replicate SEM",
                                  subset = DatatoLookAt).apply(ex_stats)

# %%
#DatatoLookAt= "Transfected == True and Transfection_Bin_Count > 500"
DatatoLookAt = MorphoString+" and ('1' in Abreviation or '2' in Abreviation or '3' in Abreviation or '4' in Abreviation or '5' in Abreviation or '6' in Abreviation)"
ex_stats = flow.ChannelStatisticOp(name = "Output",
                                   channel = GreenChannel,
                                   by = ["Sample","Transfection_Bin"],
                                   function = flow.geom_mean,
                                   subset = DatatoLookAt).apply(ex_bin)

ex_stats = flow.ChannelStatisticOp(name = "Output",
                                  channel = GreenChannel,
                                  by = ["Sample","Transfection_Bin"],
                                  function = lambda x: np.std(x) / np.sqrt(len(x)),
                                  statistic_name = "Replicate SEM",
                                  subset = DatatoLookAt).apply(ex_stats)

# %%
test["Threshold"]["False"]

# %%
DatatoLookAt = MorphoString + " and ('4' in Abreviation)"
ex_stats = flow.ChannelStatisticOp(name = "Output",
                                   channel = GreenChannel,
                                   by = ["Sample","Transfection_Bin"],
                                   function = flow.geom_mean,
                                   subset = DatatoLookAt).apply(ex_bin)
thresh_op = flow.ThresholdOp(name = 'Threshold',
                             channel = 'Pacific Blue-A',
                             threshold = 100)
tv = thresh_op.default_view(huefacet = "Sample",scale = 'log')
tv.plot(ex_stats)
ex2 = thresh_op.apply(ex_stats)
ex2.data.groupby('Threshold').size()

# %%
np.unique(ex_stats.data)

# %%
thresh_op = flow.ThresholdOp(name = 'Threshold',
                             channel = 'Pacific Blue-A',
                             threshold = 10000)
tv = thresh_op.default_view(scale = 'log')
tv.plot(ex_bin)
ex2 = thresh_op.apply(ex_bin)
ex2.data.groupby('Threshold').size()

# %%
flow.HistogramView(channel = "FITC-A",
                  scale = "log",
                  huefacet = "Sample").plot(ex_stats)

# %%
flow.HistogramView(channel = "FITC-A",
                  scale = "log",
                  huefacet = "Sample").plot(ex_stats)

# %%
#DatatoLookAt= "Transfected == True and Transfection_Bin_Count > 500"
DatatoLookAt = MorphoString + " and ('13' in Abreviation or '14' in Abreviation or '15' in Abreviation or '16' in Abreviation)"
ex_stats = flow.ChannelStatisticOp(name = "Output",
                                   channel = BlueChannel,
                                   by = ["Sample","Transfection_Bin"],
                                   function = flow.geom_mean,
                                   subset = DatatoLookAt).apply(ex_bin)

ex_stats = flow.ChannelStatisticOp(name = "Output",
                                  channel = BlueChannel,
                                  by = ["Sample","Transfection_Bin"],
                                  function = lambda x: np.std(x) / np.sqrt(len(x)),
                                  statistic_name = "Replicate SEM",
                                  subset = DatatoLookAt).apply(ex_stats)

# %%
test = flow.Stats1DView(statistic = ("Output", "geom_mean"),
                 variable = "Transfection_Bin",
                 huefacet = "Sample",
                 xscale = "log",
                 #yscale = "log",
                 error_statistic = ("Output","Replicate SEM")).plot(ex_stats)
plt.xlim((1,100000));
plt.ylim((1,200000));
plt.yscale('log')
h = plt.gcf()
#h.savefig('output vs geom_mean')

# %%
DataToLookAt = MorphoString+" and ('3' in Abreviation or '4' in Abreviation or '5' in Abreviation or '6' in Abreviation)"

flow.ScatterplotView(xchannel = GreenChannel,
                     ychannel = BlueChannel,
                     #yscale = "log",
                     subset = DatatoLookAt).plot(ex_calib, alpha = 0.5)
plt.xscale('log')
plt.yscale('log')
plt.xlim((1,300000));  
plt.ylim((1,300000));

# %%
flow.ScatterplotView(xchannel = RedChannel,
                     ychannel = BlueChannel,
                     #yscale = "log",
                     subset = DataToLookAt).plot(ex_calib, alpha = 0.5)
plt.xscale('log')
plt.yscale('log')
plt.xlim((1,300000));  
plt.ylim((1,300000));

# %%
flow.ScatterplotView(xchannel = RedChannel,
                     ychannel = iRedChannel,
                     #yscale = "log",
                     subset = DataToLookAt).plot(ex_calib, alpha = 0.5)
plt.xscale('log')
plt.yscale('log')
plt.xlim((1,300000));  
plt.ylim((1,300000));

# %%
plt.figure(figsize=(10,10))
gMeanStatsData = ex_stats.statistics[("Output", 'geom_mean')]
gErrStatsData = ex_stats.statistics[("Output", 'Replicate SEM')]

# %%
gMeanStatsData

# %%
PosName = 'PRMPv10-Pos-1'
PlusName = '1xPRMPv10-100P-1'
MinusName = '1xPRMPv10-0P-1'

plt.figure(figsize=(8,6))
BinValue = 3162.0000 
gMeanStatsData = ex_stats.statistics[("Output", 'geom_mean')]
gErrStatsData = ex_stats.statistics[("Output", 'Replicate SEM')]
means = [gMeanStatsData[PosName][BinValue],
         gMeanStatsData[PlusName][BinValue],
         gMeanStatsData[MinusName][BinValue]]
errs  = [gErrStatsData[PosName][BinValue],
         gErrStatsData[PlusName][BinValue],
         gErrStatsData[MinusName][BinValue]]

font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 1}

plt.rc('font', **font)
bar_width = 0.5
plt.bar(np.arange(3)+1, means, 
                 bar_width,
                 log = True,
                 yerr=errs,
                 tick_label = ['Positive','PlusPh','NoPh'],
                 error_kw=dict(lw=5, capsize=5, capthick=3))
plt.tick_params(labelsize=18)
plt.ylim([1,100000])
plt.xlim([0,4])
plt.ylabel('Output In A.U.',fontsize=50,fontweight='bold')
print('Plus Minus Ph Fold Change',gMeanStatsData[PlusName][BinValue]/gMeanStatsData[MinusName][BinValue])
print('Pos Minus Ph Fold Change',gMeanStatsData[PosName][BinValue]/gMeanStatsData[MinusName][BinValue])
